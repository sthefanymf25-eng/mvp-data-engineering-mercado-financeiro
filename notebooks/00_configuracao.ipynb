# %%
dados_teste = [
    ("Bitcoin", "BTC"),
    ("Ethereum", "ETH"),
    ("Solana", "SOL"),
    ("XRP", "XRP")
]

df_teste = spark.createDataFrame(
    dados_teste,
    ["ativo", "codigo"]
)

display(df_teste)

# %%
spark

# %%
print("MVP Data Engineering - Mercado Financeiro e Criptomoedas")
